# %% [markdown]
# <a href="https://colab.research.google.com/github/mrunalithaware/SQL-EDA-Project/blob/main/Mrunali_SQL_EDA_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Project Name - Play **Store**(SQL Project)

# %% [markdown]
# # Project Type - EDA
#
# # Contribution - Individual

# %% [markdown]
# # **GitHub Link -**

# %%
# !pip install pandas pandasql

# %%
import pandas as pd
import sqlite3

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/DATA SETS/Play Store Data.csv', encoding='Latin')
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite â FREE Live Cool Themes, Hid...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
conn = sqlite3.connect('Playstore.db')

df.to_sql('Playstore', conn, if_exists='replace', index=False)

conn.close()

# %%
conn = sqlite3.connect('Playstore.db')

conn.commit()
users = pd.read_sql_query('''SELECT * From Playstore''',conn)
conn.close()

# %%
conn = sqlite3.connect('Playstore.db')
df = pd.read_sql_query(
    '''SELECT * FROM Playstore''', conn)
conn.close()

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
conn = sqlite3.connect('Playstore.db')
pd.read_sql_query('''

select distinct App
from Playstore

''', conn)
# Out:
#                                                     App
# 0        Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                   Coloring book moana
# 2     U Launcher Lite â FREE Live Cool Themes, Hid...
# 3                                 Sketch - Draw & Paint
# 4                 Pixel Draw - Number Art Coloring Book
# ...                                                 ...
# 9655                                   Sya9a Maroc - FR
# 9656                   Fr. Mike Schmitz Audio Teachings
# 9657                             Parkinson Exercices FR
# 9658                      The SCP Foundation DB fr nn5n
# 9659      iHoroscope - 2018 Daily Horoscope & Astrology
#
# [9660 rows x 1 columns]

# %%
conn = sqlite3.connect('Playstore.db')

# %%
pd.read_sql_query('''
select distinct Category
from Playstore

''', conn)
# Out:
#                Category
# 0        ART_AND_DESIGN
# 1     AUTO_AND_VEHICLES
# 2                BEAUTY
# 3   BOOKS_AND_REFERENCE
# 4              BUSINESS
# 5                COMICS
# 6         COMMUNICATION
# 7                DATING
# 8             EDUCATION
# 9         ENTERTAINMENT
# 10               EVENTS
# 11              FINANCE
# 12       FOOD_AND_DRINK
# 13   HEALTH_AND_FITNESS
# 14       HOUSE_AND_HOME
# 15   LIBRARIES_AND_DEMO
# 16            LIFESTYLE
# 17                 GAME
# 18               FAMILY
# 19              MEDICAL
# 20               SOCIAL
# 21             SHOPPING
# 22          PHOTOGRAPHY
# 23               SPORTS
# 24     TRAVEL_AND_LOCAL
# 25                TOOLS
# 26      PERSONALIZATION
# 27         PRODUCTIVITY
# 28            PARENTING
# 29              WEATHER
# 30        VIDEO_PLAYERS
# 31   NEWS_AND_MAGAZINES
# 32  MAPS_AND_NAVIGATION
# 33                  1.9

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
pd.read_sql_query('''
select distinct Rating,app
from Playstore
order by rating desc
''', conn)
# Out:
#       Rating                                      App
# 0       19.0  Life Made WI-Fi Touchscreen Photo Frame
# 1        5.0             Hojiboy Tojiboyev Life Hacks
# 2        5.0            American Girls Mobile Numbers
# 3        5.0                             Awake Dating
# 4        5.0                    Spine- The dating app
# ...      ...                                      ...
# 9673     NaN                                Cardio-FR
# 9674     NaN                       Naruto & Boruto FR
# 9675     NaN                 payermonstationnement.fr
# 9676     NaN                                 FR Forms
# 9677     NaN                   Parkinson Exercices FR
#
# [9678 rows x 2 columns]

# %%
pd.read_sql_query('''
select distinct reviews
from Playstore
order by reviews desc
''', conn)
# Out:
#       Reviews
# 0        9992
# 1         999
# 2        9975
# 3        9971
# 4         997
# ...       ...
# 5997  1000417
# 5998      100
# 5999       10
# 6000        1
# 6001        0
#
# [6002 rows x 1 columns]

# %%
pd.read_sql_query('''
select distinct Installs, Size, Type
from Playstore
order by Installs desc
''', conn)
# Out:
#           Installs                Size  Type
# 0             Free              1,000+     0
# 1     500,000,000+  Varies with device  Free
# 2     500,000,000+                 11M  Free
# 3     500,000,000+                 40M  Free
# 4     500,000,000+                 74M  Free
# ...            ...                 ...   ...
# 2833            0+                3.2M  Paid
# 2834            0+                2.6M  Paid
# 2835            0+                1.4M  Paid
# 2836            0+                 40M  Paid
# 2837             0  Varies with device  None
#
# [2838 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
pd.read_sql_query('''
SELECT "Current Ver", "Android Ver"
from Playstore
order by "Current Ver" desc
limit 2
''', conn)
# Out:
#      Current Ver Android Ver
# 0  version 0.994  3.2 and up
# 1     v8[1.0.10]  2.3 and up

# %%
pd.read_sql_query('''
SELECT "Android Ver"
from Playstore
order by "Android Ver" desc
limit 2
''', conn)
# Out:
#           Android Ver
# 0  Varies with device
# 1  Varies with device

# %%
pd.read_sql_query('''
select distinct Type, Price
from Playstore
order by Price desc
''', conn)
# Out:
#     Type     Price
# 0      0  Everyone
# 1   Free         0
# 2   None         0
# 3   Paid     $9.99
# 4   Paid     $9.00
# ..   ...       ...
# 89  Paid     $1.26
# 90  Paid     $1.20
# 91  Paid     $1.04
# 92  Paid     $1.00
# 93  Paid     $0.99
#
# [94 rows x 2 columns]
